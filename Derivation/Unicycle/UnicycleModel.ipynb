# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Simulations
#
# First we need to somehow verify the model.

# %%
from Runner import run_simulation

run_simulation([1e-6, 1e-6, 1, 0, 0, 0, 0, 3, 0, 0], [0, 5.0], recalculate=False)

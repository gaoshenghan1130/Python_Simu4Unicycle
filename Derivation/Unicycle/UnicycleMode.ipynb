# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Simulations
#
# First we need to somehow verify the model.

# %%
from Runner import run_simulation

run_simulation([1e-6, 1e-6, 1e-6, 1e-6, 1e-6, 0, 0, 0, 0, 0], [0, 1.0])
# Out:
# Evaluating M and f at t=0.00, state=[1.e-06 1.e-06 1.e-06 1.e-06 1.e-06 0.e+00 0.e+00 0.e+00 0.e+00 0.e+00], controls={'T_W': 0.0, 'F_L': 0.0}, params={'R': 0.25, 'h': 0.1, 'm': 1, 'm_w': 1.5, 'm_l': 0.5, 'g': 9.81}
# Evaluating M and f at t=0.00, state=[ 1.00000000e-06  1.00000000e-06  1.00000000e-06  1.00000000e-06
#   1.00000000e-06 -2.23606574e-08  2.45245920e-14 -5.40983647e-14
#  -2.09180344e-14  4.84000036e-13], controls={'T_W': 0.0, 'F_L': 0.0}, params={'R': 0.25, 'h': 0.1, 'm': 1, 'm_w': 1.5, 'm_l': 0.5, 'g': 9.81}
# Evaluating M and f at t=0.00, state=[ 1.00000000e-06  1.00000000e-06  1.00000000e-06  1.00000000e-06
#   1.00000000e-06 -4.47213148e-07  4.90491840e-13 -1.08196729e-12
#  -4.18360687e-13  9.68000072e-12], controls={'T_W': 0.0, 'F_L': 0.0}, params={'R': 0.25, 'h': 0.1, 'm': 1, 'm_w': 1.5, 'm_l': 0.5, 'g': 9.81}
# Evaluating M and f at t=0.00, state=[ 9.99999972e-07  1.00000000e-06  1.00000000e-06  1.00000000e-06
# ...
